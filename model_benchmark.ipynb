# %%
import pandas as pd

from model_benchmark_utils import *

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 10)

# %% [markdown]
# ## Answer quality functions

# %%
def uniform(answer, description):
    return 1.0

# %%
def preferred_length(answer, prompt):
    split_answer = answer.split(' ')
    word_count_factor = 1.0 if len(split_answer) in [5, 6] else 0.1
    return word_count_factor

# %%
def most_common_words(answer, prompt):
    answer_word_list = answer.upper().split(" ")
    prompt_word_list = prompt.upper().split(" ")
    number_of_common_words = len(list(set(prompt_word_list) & set(answer_word_list)))

    return number_of_common_words / float(len(answer_word_list))

# %% [markdown]
# ## model-1 performance evaluation

# %% [markdown]
# This was the first model trained - no training data processing was involved except from wrapping description and names in meta markers. Model was training for 4600 steps on single GPU. Average loss at that point was 0.19. Since next iteration achieved better results with average loss of 0.35 it could mean that at this point model-1 was already overfitted, or otherwise broken. Tensorboard graph - and most probably model itself - is messed up from multiple training attempts with different training parameters. Because of that it a was throw away model to figure out whole process of training and generating answers for submission.
#
# Submission was generated with a heuristics that favoured answers having most words in common with the description.
#
# Model scored 0.14 in the challenge test which is slightly above tested maximum potential (see below)

# %%
model_1_answers, model_1_score = evaluate_all_test_sets_of_model(1, most_common_words)

# %% [markdown]
# Best answers:

# %%
model_1_answers.sort_values(by='score', ascending=False).head(10)
# Out:
#                               name  \
# 34        WOVEN BANANA LEAF BASKET
# 87  CHRISTMAS PARACHUTE DECORATION
# 43         GREEN IRON WATERING CAN
# 95    METALLIC-EFFECT SKINNY JEANS
# 54       LARGE ROUND BAMBOO BASKET
# 49                BLUE HOLE 100 ML
# 18           STAR PRINT FLAT SHEET
# 17                    WOODEN STOOL
# 76             ZARA ROSE EDT 90 ML
# 99               WOODEN DOOR KNOBS
#
#                                           description  \
# 34    Woven banana leaf basket with contrast handles.
# 87                    Christmas parachute decoration.
# 43  Green iron watering can with a brass sprinkler...
# 95  Metallic-effect skinny jeans featuring a five-...
# 54  Large round bamboo basket with woven rattan sh...
# 49  ZARA BLUE HOLE EDT 100 ML (3.4 FL. OZ). <br/><...
# 18  Flat sheet in 200 thread count cotton percale ...
# 17                                      Wooden stool.
# 76  ZARA ROSE EDT 90 ML (3.04 FL. OZ). <br/><br/>F...
# 99                      Wooden door knobs (set of 2).
#
#                                               answers  score
# 34  WOVEN BANANA LEAF BASKET WITH CONTRAST HANDLES...    1.0
# 87  CHRISTMAS MOTHER TREE DECORATION, CHRISTMAS CH...    1.0
# 43  GREEN IRON WATERING CAN WITH BRASS SYNTHETIC H...    1.0
# 95  SOFT DESIGN LIGHTWEIGHT 9.5 ML / 3.38 OZ, THE ...    1.0
# 54  LARGE ROUND BAMBOO BASKET, LARGE ROUND BAMBOO ...    1.0
# 49  BLUE HOLE 100 ML / 3.38 OZ, BLUE HOLE 8.34ML /...    1.0
# 18  STAR-SHAPED SHEET WITH HEMSTITCHING, ELEPHANT ...    1.0
# 17  WOODEN STOOL, TWO-TONE WOODEN STOOL, WARM WOOD...    1.0
# 76  ZARA ROSE EDT 90 ML / 3.04 OZ + ZARA ROSE EDT ...    1.0
# 99  WOODEN DOOR KNOBS (SET OF 2), WOODEN DOOR KNOB...    1.0

# %% [markdown]
# Worst answers:

# %%
model_1_answers.sort_values(by='score').head(10)
# Out:
#                                 name  \
# 0                      SMILE T-SHIRT
# 31            CHECKED PINAFORE DRESS
# 30                   RUSTIC TROUSERS
# 29            SHIRRED WAIST TROUSERS
# 28               ROUND FLOOR CUSHION
# 27                  FLOWERS HAIRBAND
# 26  RELAXED FIT HI-RISE FLARED JEANS
# 25       COMBINED HERRINGBONE BRACES
# 24    FLOWING PRINTED BERMUDA SHORTS
# 23               TECHNICAL OVERSHIRT
#
#                                           description  \
# 0   Long sleeve T-shirt with a round neckline and ...
# 31  Pinafore dress with a round neckline and strap...
# 30     High-waist trousers with an elastic waistband.
# 29  High-waist trousers with an elastic waist. Fea...
# 28  Round padded floor cushion with a star print. ...
# 27     Headband with bow appliqué and a floral print.
# 26  Faded high-waist jeans with a five-pocket desi...
# 25  Adjustable elastic braces. Metal brace clips w...
# 24  High-waist Bermuda shorts with an elastic wais...
# 23  Relaxed fit overshirt made of technical fabric...
#
#                                               answers  score
# 0   PLUSH T-SHIRT WITH AN EMBOSSED TEXT, BLACK STR...    0.0
# 31  ESSENCE PINAFORE DRESS WITH FEATURING FRONT, L...    0.0
# 30  HIGH-WAIST TROUSERS, HIGH-WAIST TEXTURED TROUS...    0.0
# 29  TROUSERS WITH CONTRAST WAIST, HOUNDSTOOTH WOOL...    0.0
# 28  STAR PRINT ROUND PADDED FLOOR CUSHION, ROUND P...    0.0
# 27  BELT BAG WITH FLORAL PRINT, FOAM BAND WITH FLO...    0.0
# 26  Z1975 HIGH-WAIST JEANS WITH FEATURING WAIST, F...    0.0
# 25  ADJUSTABLE LEATHER SCARF, ADJUSTABLE METAL BRA...    0.0
# 24  LEOPARD PRINT BERMUDA SHORTS, ELASTIC WAISTBAN...    0.0
# 23  RESEARCH TECHNICAL MOUSEIRT, RUBBERISED OVERSH...    0.0

# %% [markdown]
# Tested maximum potential (answers in perfect order):

# %%
model_potential(model_1_answers)
# Out:
# 0.126

# %% [markdown]
# Tested score of unsorted answers:

# %%
model_1_score
# Out:
# 0.08087961104174585

# %% [markdown]
# ## model-2 performance evaluation

# %% [markdown]
# Another attempt to train was focused on utilizing both GPUs and training time optimization. Enabling multi_gpu flag caused more memory pressure on the first card while the second one's memory allocation was only 60%. In order to decrease memory allocation on the first card I enabled use_memory_saving_gradients option which also forced disabling accumulate_gradients option. Learning rate was increased from default 0.0001 to 0.0002
#
# Model was training on 2 GPUs with batch size of 10. After 1400 steps average loss was 0.35

# %%
model_2_answers, model_2_score = evaluate_all_test_sets_of_model(2, most_common_words)

# %% [markdown]
# Best answers:

# %%
model_2_answers.sort_values(by='score', ascending=False).head(10)
# Out:
#                           name  \
# 93   GOLD LEAF TEALIGHT HOLDER
# 62  TOP WITH RHINESTONE STRAPS
# 42               BEAR BACKPACK
# 96  LEAF PRINT SWIMMING TRUNKS
# 29  ROUND WOODEN JEWELLERY BOX
# 52        MOUSE FLEECE BLANKET
# 49           STRAW BEACH VISOR
# 4     GREENISH GLASS SOAP DISH
# 58        BOX PLEAT MINI SKIRT
# 92               TUBEROSE 10ML
#
#                                           description  \
# 93       Glass tealight holder with gold leaf detail.
# 62  Top with a straight neckline. Thin metal strap...
# 42  Playful backpack with decorative teddy bear an...
# 96  Swimming trunks with a leaf print design and a...
# 29  Round wooden jewellery box with a mirror insid...
# 52  Fleece blanket featuring a polka dot backgroun...
# 49                                 Straw beach visor.
# 4                           Greenish glass soap dish.
# 58  High­waist mini skirt with a short-style linin...
# 92  ZARA TUBEROSE EDT 10ML (0.34 FL. OZ). <br/><br...
#
#                                               answers  score
# 93  TEALIGHT HOLDER WITH LEAF DETAIL, GREEN TEALIG...    1.0
# 62  GEM BUTTON TOP TRF, LACE TOP WITH STRAIGHT NEC...    1.0
# 42  BEAR BACKPACK, ANIMAL PRINT BACKPACK, BEAR BAC...    1.0
# 96  LINEN BUSTIER SWIMMING TRUNKS, INFUSED SPARKLY...    1.0
# 29  ROUND WOODEN JEWELLERY BOX, LARGE MIRRORED WOR...    1.0
# 52  MOUSE FLEECE BLANKET, ANIMAL AND MOUSE © DISNE...    1.0
# 49  BEACH VISOR, STRAW BEACH VISOR, STRAW SNEAKERS...    1.0
# 4   GREENISH GLASS DISPENSER, GREENISH GLASS DISH,...    1.0
# 58  BOX PLEAT MINI SKIRT, BOX PLEAT SKIRT, BOX PLE...    1.0
# 92  TUBEROSE 10ML, TUBEROSE EDT 10 ML / 0.34 OZ, T...    1.0

# %% [markdown]
# Worst answers:

# %%
model_2_answers.sort_values(by='score').head(10)
# Out:
#                                       name  \
# 0                            SMILE T-SHIRT
# 62                         JACQUARD BLAZER
# 63                  TRAVELER SUIT TROUSERS
# 64                          FAMILY T-SHIRT
# 65                           SPARKLY DRESS
# 66  POPLIN TOP WITH CUTWORK EMBROIDERY TRF
# 68                        STRIPE PRINT TOP
# 69                       FUR CUSHION COVER
# 70                  PRINTED MIDI DRESS TRF
# 60         SUEDE FLAT MULES WITH JUTE SOLE
#
#                                           description  \
# 0   Long sleeve T-shirt with a round neckline and ...
# 62  Blazer with a round collar and long sleeves. F...
# 63  Trousers made of textured bi-stretch, easy-to-...
# 64  Short sleeve T-shirt with a round neck and slo...
# 65  Dress featuring a straight neckline and ruffle...
# 66  Crop top with a wide straight neckline and sho...
# 68  Top with an adjustable buttoned high neck, lon...
# 69  Faux fur cushion cover. Cushion filling not in...
# 70  Dress with a round neck and long sleeves. Feat...
# 60  Sand-coloured leather flat mules. Split suede ...
#
#                                               answers  score
# 0   PRINTED T-SHIRT, FLORAL PRINT T-SHIRT, FOOTBAL...    0.0
# 62  FAUX LEATHER BLAZER, TAFFETA CHECK SUIT BLAZER...    0.0
# 63  EASY-TO-IRON TECHNICAL TROUSERS, SLIM FIT TROU...    0.0
# 64  ANIMAL PRINT STRIPE T-SHIRT, LONGLINE SLOGAN T...    0.0
# 65  RUFFLED SHIRT DRESS, SHINY TEXTURED DRESS WITH...    0.0
# 66  LACE ORGANZA TOP, CUT OUT MINI CROP TOP, PRINT...    0.0
# 68  FAUX LEATHER TOP, PLEATED TOP, ORGANZA PRINT T...    0.0
# 69  FAUX FUR QUILDREN'S CUSHION COVER, FAUX FUR CU...    0.0
# 70  PLEATED DRESS, SATEEN DRESS TRF, CHECK DRESS, ...    0.0
# 60  SQUARE-TOE LEATHER SHOES/SUEDE HEEL SHOT, LEAT...    0.0

# %% [markdown]
# Tested maximum potential:

# %%
model_potential(model_2_answers)
# Out:
# 0.424

# %% [markdown]
# Tested score of unsorted answers:

# %%
model_2_score
# Out:
# 0.23222571384786073

# %% [markdown]
# ## model-2.1 performance evaluation

# %% [markdown]
# Model 2.1 is even more finetuned model 2. After another 1200 steps average loss was at 0.247 and tested score is significantly improved

# %%
model_2_1_answers, model_2_1_score = evaluate_all_test_sets_of_model('2.1', most_common_words)

# %% [markdown]
# Best answers:

# %%
model_2_answers.sort_values(by='score', ascending=False).head(10)
# Out:
#                           name  \
# 93   GOLD LEAF TEALIGHT HOLDER
# 62  TOP WITH RHINESTONE STRAPS
# 42               BEAR BACKPACK
# 96  LEAF PRINT SWIMMING TRUNKS
# 29  ROUND WOODEN JEWELLERY BOX
# 52        MOUSE FLEECE BLANKET
# 49           STRAW BEACH VISOR
# 4     GREENISH GLASS SOAP DISH
# 58        BOX PLEAT MINI SKIRT
# 92               TUBEROSE 10ML
#
#                                           description  \
# 93       Glass tealight holder with gold leaf detail.
# 62  Top with a straight neckline. Thin metal strap...
# 42  Playful backpack with decorative teddy bear an...
# 96  Swimming trunks with a leaf print design and a...
# 29  Round wooden jewellery box with a mirror insid...
# 52  Fleece blanket featuring a polka dot backgroun...
# 49                                 Straw beach visor.
# 4                           Greenish glass soap dish.
# 58  High­waist mini skirt with a short-style linin...
# 92  ZARA TUBEROSE EDT 10ML (0.34 FL. OZ). <br/><br...
#
#                                               answers  score
# 93  TEALIGHT HOLDER WITH LEAF DETAIL, GREEN TEALIG...    1.0
# 62  GEM BUTTON TOP TRF, LACE TOP WITH STRAIGHT NEC...    1.0
# 42  BEAR BACKPACK, ANIMAL PRINT BACKPACK, BEAR BAC...    1.0
# 96  LINEN BUSTIER SWIMMING TRUNKS, INFUSED SPARKLY...    1.0
# 29  ROUND WOODEN JEWELLERY BOX, LARGE MIRRORED WOR...    1.0
# 52  MOUSE FLEECE BLANKET, ANIMAL AND MOUSE © DISNE...    1.0
# 49  BEACH VISOR, STRAW BEACH VISOR, STRAW SNEAKERS...    1.0
# 4   GREENISH GLASS DISPENSER, GREENISH GLASS DISH,...    1.0
# 58  BOX PLEAT MINI SKIRT, BOX PLEAT SKIRT, BOX PLE...    1.0
# 92  TUBEROSE 10ML, TUBEROSE EDT 10 ML / 0.34 OZ, T...    1.0

# %% [markdown]
# Worst answers

# %%
model_2_answers.sort_values(by='score').head(10)
# Out:
#                                       name  \
# 0                            SMILE T-SHIRT
# 62                         JACQUARD BLAZER
# 63                  TRAVELER SUIT TROUSERS
# 64                          FAMILY T-SHIRT
# 65                           SPARKLY DRESS
# 66  POPLIN TOP WITH CUTWORK EMBROIDERY TRF
# 68                        STRIPE PRINT TOP
# 69                       FUR CUSHION COVER
# 70                  PRINTED MIDI DRESS TRF
# 60         SUEDE FLAT MULES WITH JUTE SOLE
#
#                                           description  \
# 0   Long sleeve T-shirt with a round neckline and ...
# 62  Blazer with a round collar and long sleeves. F...
# 63  Trousers made of textured bi-stretch, easy-to-...
# 64  Short sleeve T-shirt with a round neck and slo...
# 65  Dress featuring a straight neckline and ruffle...
# 66  Crop top with a wide straight neckline and sho...
# 68  Top with an adjustable buttoned high neck, lon...
# 69  Faux fur cushion cover. Cushion filling not in...
# 70  Dress with a round neck and long sleeves. Feat...
# 60  Sand-coloured leather flat mules. Split suede ...
#
#                                               answers  score
# 0   PRINTED T-SHIRT, FLORAL PRINT T-SHIRT, FOOTBAL...    0.0
# 62  FAUX LEATHER BLAZER, TAFFETA CHECK SUIT BLAZER...    0.0
# 63  EASY-TO-IRON TECHNICAL TROUSERS, SLIM FIT TROU...    0.0
# 64  ANIMAL PRINT STRIPE T-SHIRT, LONGLINE SLOGAN T...    0.0
# 65  RUFFLED SHIRT DRESS, SHINY TEXTURED DRESS WITH...    0.0
# 66  LACE ORGANZA TOP, CUT OUT MINI CROP TOP, PRINT...    0.0
# 68  FAUX LEATHER TOP, PLEATED TOP, ORGANZA PRINT T...    0.0
# 69  FAUX FUR QUILDREN'S CUSHION COVER, FAUX FUR CU...    0.0
# 70  PLEATED DRESS, SATEEN DRESS TRF, CHECK DRESS, ...    0.0
# 60  SQUARE-TOE LEATHER SHOES/SUEDE HEEL SHOT, LEAT...    0.0

# %% [markdown]
# Tested maximum potential:

# %%
model_potential(model_2_1_answers)
# Out:
# 0.58

# %% [markdown]
# Tested score of unsorted answers:

# %%
model_2_1_score
# Out:
# 0.29293636154047076

# %% [markdown]
# ## model-2.1 performance evaluation

# %%
model_2_2_answers, model_2_2_score = evaluate_all_test_sets_of_model('2.2', uniform)

# %%
model_1_answers.sort_values(by='score', ascending=False).head(50)
# Out:
#                                         name  \
# 34                  WOVEN BANANA LEAF BASKET
# 87            CHRISTMAS PARACHUTE DECORATION
# 43                   GREEN IRON WATERING CAN
# 95              METALLIC-EFFECT SKINNY JEANS
# 54                 LARGE ROUND BAMBOO BASKET
# 49                          BLUE HOLE 100 ML
# 18                     STAR PRINT FLAT SHEET
# 17                              WOODEN STOOL
# 76                       ZARA ROSE EDT 90 ML
# 99                         WOODEN DOOR KNOBS
# 76                         SLOGAN SWEATSHIRT
# 94                       ZARA ULTIMATTE MM01
# 8                   SNOOPY ® PEANUTS T-SHIRT
# 84                 FAUX LEATHER BIKER JACKET
# 51                             WOODEN MIRROR
# 68                   SNOOPY ® PEANUTS SHORTS
# 64            SNOOPY ® PEANUTS PRINT T-SHIRT
# 56                    BAMBI © DISNEY T-SHIRT
# 91                  MICROFIBRE DUVET FILLING
# 49                         STRAW BEACH VISOR
# 82                      SATIN HIPSTER BRIEFS
# 94                      WOODEN BEDSIDE TABLE
# 4             EMBROIDERED KNIT CUSHION COVER
# 42                            GOLD METAL BOX
# 14                                 SHORT HAT
# 55                      PLAIN BIKINI BOTTOMS
# 30                       FAUX FUR SWEATSHIRT
# 4                   HAIR CLIP WITH SATIN BOW
# 74                      CHECK BERMUDA SHORTS
# 83                          CASHMERE SWEATER
# 4                   GREENISH GLASS SOAP DISH
# 93                 GOLD LEAF TEALIGHT HOLDER
# 70                    FAUX FUR CROSSBODY BAG
# 69                       KNIT JACQUARD SNOOD
# 20             LEATHER HEELED PLATFORM MULES
# 47                  STAINLESS STEEL COLANDER
# 37         EARTHENWARE DINNER PLATE WITH RIM
# 72                                  CROP TOP
# 32                            SLEEVELESS TOP
# 66                    PUFFER GILET WITH HOOD
# 33                           COTTON SNEAKERS
# 46   LEATHER ANKLE BOOTS WITH GEOMETRIC SOLE
# 10              RAISED DESIGN ICE-CREAM DISH
# 86                      BLACK MARBLE ASHTRAY
# 85                          PRINTED LEGGINGS
# 47  DYED THREAD COTTON TEA TOWEL (PACK OF 3)
# 6                  TEXTURED DRESS WITH SEAMS
# 6                       CROPPED DENIM JACKET
# 53                     SHEEP SOFT TOY RATTLE
# 46                         CONTRAST TRAINERS
#
#                                           description  \
# 34    Woven banana leaf basket with contrast handles.
# 87                    Christmas parachute decoration.
# 43  Green iron watering can with a brass sprinkler...
# 95  Metallic-effect skinny jeans featuring a five-...
# 54  Large round bamboo basket with woven rattan sh...
# 49  ZARA BLUE HOLE EDT 100 ML (3.4 FL. OZ). <br/><...
# 18  Flat sheet in 200 thread count cotton percale ...
# 17                                      Wooden stool.
# 76  ZARA ROSE EDT 90 ML (3.04 FL. OZ). <br/><br/>F...
# 99                      Wooden door knobs (set of 2).
# 76  Round neck sweatshirt with long sleeves and cu...
# 94  ZARA ULTIMATTE MM01 MATTE LIPSTICK 3.5 GR (0.1...
# 8   Short sleeve T-shirt with a round neckline. Fe...
# 84  Faux leather biker jacket with snap-button tab...
# 51          Wooden mirror in the shape of a teardrop.
# 68  Shorts with an elastic waistband and decorativ...
# 64  Loose-fitting T-shirt with a round neckline, s...
# 56  Short sleeve T-shirt with a round neckline. BA...
# 91  Microfibre Duvet Filling. Composition of filli...
# 49                                 Straw beach visor.
# 82  Satin hipster briefs.<br/>This item must be re...
# 94  Wooden bedside table featuring a raised design...
# 4   Knit cushion cover with embroidered detail. Cu...
# 42  Glass box with gold metal edges and three sepa...
# 14  Short hat with turn-up brim and adjustable fas...
# 55                Bikini bottoms with a plain design.
# 30  Faux fur sweatshirt with a hood and long sleev...
# 4                         Hair clip with a satin bow.
# 74  Bermuda shorts featuring an adjustable inner w...
# 83  Sweater made of a cashmere and wool blend. V-n...
# 4                           Greenish glass soap dish.
# 93       Glass tealight holder with gold leaf detail.
# 70  Crossbody bag with faux fur on the body, a cha...
# 69                   Knit snood with jacquard motifs.
# 20  Leather heeled mules available in several colo...
# 47  Lacquered stainless steel colander. <br/>Light...
# 37                 Earthenware dinner plate with rim.
# 72  Crop top with a V-neckline and short sleeves. ...
# 32  Sleeveless top with a round neckline, side ven...
# 66  Puffer gilet with a hood and zip-up front. Adj...
# 33  Sneakers in 100% cotton. Fastening with two ho...
# 46  Brown leather ankle boots with a split suede f...
# 10  Ice-cream dish with a raised design. Capacity:...
# 86                        Small black marble ashtray.
# 85  Leggings with an elastic waistband and all-ove...
# 47  Dyed thread cotton tea towel. Sold in packs of...
# 6   Textured dress featuring a round neckline, 3/4...
# 6   Cropped collared jacket with long sleeves. Fea...
# 53           Soft toy rattle in the shape of a sheep.
# 46  White trainers. Combination of materials on th...
#
#                                               answers     score
# 34  WOVEN BANANA LEAF BASKET WITH CONTRAST HANDLES...  1.000000
# 87  CHRISTMAS MOTHER TREE DECORATION, CHRISTMAS CH...  1.000000
# 43  GREEN IRON WATERING CAN WITH BRASS SYNTHETIC H...  1.000000
# 95  SOFT DESIGN LIGHTWEIGHT 9.5 ML / 3.38 OZ, THE ...  1.000000
# 54  LARGE ROUND BAMBOO BASKET, LARGE ROUND BAMBOO ...  1.000000
# 49  BLUE HOLE 100 ML / 3.38 OZ, BLUE HOLE 8.34ML /...  1.000000
# 18  STAR-SHAPED SHEET WITH HEMSTITCHING, ELEPHANT ...  1.000000
# 17  WOODEN STOOL, TWO-TONE WOODEN STOOL, WARM WOOD...  1.000000
# 76  ZARA ROSE EDT 90 ML / 3.04 OZ + ZARA ROSE EDT ...  1.000000
# 99  WOODEN DOOR KNOBS (SET OF 2), WOODEN DOOR KNOB...  1.000000
# 76  SPECIAL EDITION RIBBED SWEATSHIRT, BASIC RIBBE...  1.000000
# 94  ZARA ULTIMATTE MM01, ULTIMATTE MM01 MATTE LIPS...  1.000000
# 8   PATCHWORK SWEATSHIRT WITH ROUND NECKLINE, SNOO...  1.000000
# 84  FAUX LEATHER BIKER JACKET, FAUX LEATHER BIKER ...  1.000000
# 51  WOODEN MIRROR, WHITE WOODEN MIRROR, TEXTURED S...  1.000000
# 68  SNOOPY ® PEANUTS SHORTS, SNOOPY ® PEANUTS FABR...  1.000000
# 64  SNOOPY ®PEANUTS T-SHIRT, SNOOPY ® PEANUTS T-SH...  1.000000
# 56  BAMBI © DISNEY T-SHIRT, RIBBED T-SHIRT WITH BA...  1.000000
# 91  MICROFABRIC DUVET FILLING - HYPOALLERGY PLANET...  1.000000
# 49  STRAW VISOR, STRAW VISOR 8.5ML / 0.8 FL.0BIT E...  1.000000
# 82  HIPSTER HIPSTER BRIEFS, ATOM HIPSTER BRIEFS, H...  1.000000
# 94  WOODEN BEDSIDE TABLE, WAFFLE TABLE WITH A RAIS...  1.000000
# 4   KNIT SWEATER WITH BOW, LIMITED EDITION KNIT CU...  1.000000
# 42  GLASS BOX WITH GOLD METAL EDGES, ATOM WITH FUG...  0.630930
# 14  PRINTED SOCK SLEEVE BLANKET, FAUX SHEARLING MU...  0.630930
# 55  BIKINI BOTTOMS WITH A PLAIN DESIGN, BIKINI BOT...  0.630930
# 30  FAUX FUR SWEATSHIRT WITH HOOD, FAUX FUR SWEATS...  0.630930
# 4   HAS BRUSHED HEART TRF, HALTER SKIN, RAISED DES...  0.630930
# 74  BEIGE BERMUDA SHORTS, BASIC ANIMAL PRINT BERMU...  0.630930
# 83  CASHMERE AND WOOL BLEND SWEATER, WOOL BLEND SW...  0.630930
# 4   GREENISH TEALIGHT DISH, GREENISH GLASS SOAP DI...  0.630930
# 93  GLASS TEALIGHT HOLDER WITH GOLD LEAF DETAIL, S...  0.630930
# 70  METAL CLASP BAG, CROSSBODY BAG WITH FAUX FUR O...  0.630930
# 69  KNIT SCARF, COSK SWEATER WITH TRIM, POPLIN KNI...  0.630930
# 20  LEATHER MID-HEEL SUITES ANKLE CLOG ®>, LEATHER...  0.630930
# 47  LACQUERED STEEL COLANDER, ACRYLIC STEEL COLAND...  0.500000
# 37  EARTHENWARE PLATE, EARTHENWARE SPOON WITH RIM,...  0.500000
# 72  TOP WITH TIGER DESIGN TRF, RIBBED KNIT TOP, SH...  0.500000
# 32  TOP WITH STRETCH TRF, FLOCKED TEXTURED WEAVE T...  0.500000
# 66  TECHNICAL JUMPSUIT WITH PUFFER GILET, CORDUROY...  0.500000
# 33  DELUXE SNEAKERS, GREATER MOTIFS SOAP BOX, SNOO...  0.500000
# 46  BROWN LEATHER ANKLE BOOT, BROWN LEATHER ANKLE ...  0.430677
# 10  RAISED DESIGN ICE-CREAM DISH, ICE-CREAM DISH W...  0.430677
# 86  SMALL BLACK MARBLE ASHTRAY, SMALL MARBLE ASHTR...  0.386853
# 85  LIMITED EDITION LACE-UP LEGGINGS, THE GOLD AND...  0.386853
# 47  DYED THREAD COTTON TEA TOWEL (PACK OF 3), TWO-...  0.386853
# 6   MASCULINE NECKLINE BODYSUIT, KNIT MINI DRESS W...  0.386853
# 6   ANIMAL PRINT PATENT FINISH JACKET, KNIT MINI H...  0.386853
# 53  SHEEP SOFT TOY RATTLE, SOFT TOY RATTLE, SOFT T...  0.386853
# 46  WHITE TRAINERS WITH TRACK MOTIF, WHITE TRAINER...  0.356207

# %%
model_potential(model_2_2_answers)
# Out:
# 0.81125

# %%
model_2_2_score
# Out:
# 0.5653414335647854
